# %% [markdown]
# # Read-me

# %% [markdown]
# - For this project, we wanto to build a ensemble method from a combination of LightGBMClassifier, Random Forests and a Logistic Regressor.
# - To do this, firstly, we need to optimize our parameters.
# - We use bayesian optimization as it showed better than grid search (in relation to time).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import roc_auc_score, average_precision_score, classification_report
from sklearn.model_selection import train_test_split
from lib.utils import *

# %%
# !pip install lightgbm
# !pip install scikit-optimize
# Out:
# Requirement already satisfied: lightgbm in /home/kevintakano/miniconda3/lib/python3.8/site-packages (3.3.0)
# Requirement already satisfied: wheel in /home/kevintakano/miniconda3/lib/python3.8/site-packages (from lightgbm) (0.35.1)
# Requirement already satisfied: scipy in /home/kevintakano/miniconda3/lib/python3.8/site-packages (from lightgbm) (1.7.0)
# Requirement already satisfied: scikit-learn!=0.22.0 in /home/kevintakano/miniconda3/lib/python3.8/site-packages (from lightgbm) (0.24.2)
# Requirement already satisfied: numpy in /home/kevintakano/miniconda3/lib/python3.8/site-packages (from lightgbm) (1.21.1)
# Requirement already satisfied: joblib>=0.11 in /home/kevintakano/miniconda3/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/kevintakano/miniconda3/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm) (2.1.0)
# Requirement already satisfied: scikit-optimize in /home/kevintakano/miniconda3/lib/python3.8/site-packages (0.8.1)
# Requirement already satisfied: joblib>=0.11 in /home/kevintakano/miniconda3/lib/python3.8/site-packages (from scikit-optimize) (1.1.0)
# Requirement already satisfied: pyaml>=16.9 in /home/kevintakano/miniconda3/lib/python3.8/site-packages (from scikit-optimize) (21.10.1)
# Requirement already satisfied: numpy>=1.13.3 in /home/kevintakano/miniconda3/lib/python3.8/site-packages (from scikit-optimize) (1.21.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/kevintakano/miniconda3/lib/python3.8/site-packages (from scikit-optimize) (0.24.2)
# Requirement already satisfied: scipy>=0.19.1 in /home/kevintakano/miniconda3/lib/python3.8/site-packages (from scikit-optimize) (1.7.0)
# Requirement already satisfied: PyYAML in /home/kevintakano/miniconda3/lib/python3.8/site-packages (from pyaml>=16.9->scikit-optimize) (5.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/kevintakano/miniconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->scikit-optimize) (2.1.0)

# %% [markdown]
# # Load data

# %%
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
X_train = np.load('data/input/X_train.npy')
y_train = np.load('data/input/y_train.npy')
X_test = np.load('data/input/X_test.npy')
y_test = np.load('data/input/y_test.npy')

# %% [markdown]
# # Bayesian Optimization

# %% [markdown]
# ## LGBM

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.10, random_state=42)

# %%
y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from skopt import forest_minimize
from lightgbm import LGBMClassifier

def tune_lgbm(params):
    print(params)
    lr = params[0]
    max_depth = params[1]
    min_child_samples = params[2]
    subsample = params[3]
    colsample_bytree = params[4]
    n_estimators = params[5]
    
    mdl = LGBMClassifier(learning_rate=lr, num_leaves=2 ** max_depth, max_depth=max_depth, 
                         min_child_samples=min_child_samples, subsample=subsample,
                         colsample_bytree=colsample_bytree, bagging_freq=1,n_estimators=n_estimators, random_state=0, 
                         class_weight="balanced", n_jobs=6)
    mdl.fit(X_train, y_train)
    
    p = mdl.predict_proba(X_valid)[:, 1]
    
    print(roc_auc_score(y_valid, p))
    
    return -average_precision_score(y_valid, p)


space = [(1e-3, 1e-1, 'log-uniform'), # lr
          (1, 10), # max_depth
          (1, 20), # min_child_samples
          (0.05, 1.), # subsample
          (0.05, 1.), # colsample_bytree
          (100,1000), # n_estimators
          ] 

res = forest_minimize(tune_lgbm, space, random_state=160745, n_random_starts=20, n_calls=50, verbose=1)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# [0.009944912110647982, 5, 1, 0.4677107511929402, 0.49263223036174764, 272]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9669884624440781
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.2610
# Function value obtained: -0.8507
# Current minimum: -0.8507
# Iteration No: 2 started. Evaluating function at random point.
# [0.0010385556240017917, 2, 10, 0.14183771058242609, 0.7437489153990157, 249]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9467859665646338
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.0823
# Function value obtained: -0.7306
# Current minimum: -0.8507
# Iteration No: 3 started. Evaluating function at random point.
# [0.00209745522423282, 5, 6, 0.1541824778996655, 0.8682075103820793, 273]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9648928655521545
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.1297
# Function value obtained: -0.8292
# Current minimum: -0.8507
# Iteration No: 4 started. Evaluating function at random point.
# [0.016490254525097375, 9, 9, 0.6502182010234373, 0.6866210554187129, 828]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9690369672710148
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 1.1704
# Function value obtained: -0.8540
# Current minimum: -0.8540
# Iteration No: 5 started. Evaluating function at random point.
# [0.022238201581720914, 1, 8, 0.3448850990367951, 0.371803112561826, 793]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9525488580174241
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.1787
# Function value obtained: -0.7206
# Current minimum: -0.8540
# Iteration No: 6 started. Evaluating function at random point.
# [0.001803868991928055, 1, 13, 0.8899029303129179, 0.9602665861392746, 214]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9234753943960443
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.0476
# Function value obtained: -0.5736
# Current minimum: -0.8540
# Iteration No: 7 started. Evaluating function at random point.
# [0.02614950849523158, 5, 8, 0.5439512623421213, 0.7483811103274842, 817]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9702378149281846
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.4480
# Function value obtained: -0.8633
# Current minimum: -0.8633
# Iteration No: 8 started. Evaluating function at random point.
# [0.07486580971619969, 10, 1, 0.18428087097824575, 0.3261556557915816, 274]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9620555686366846
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.9266
# Function value obtained: -0.8122
# Current minimum: -0.8633
# Iteration No: 9 started. Evaluating function at random point.
# [0.052720297823142664, 2, 17, 0.5204205737014657, 0.8063097899281119, 139]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9609665646338591
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.0521
# Function value obtained: -0.7916
# Current minimum: -0.8633
# Iteration No: 10 started. Evaluating function at random point.
# [0.035432749192096984, 10, 13, 0.1530283556568924, 0.6623654100211082, 732]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9669295973628443
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.8884
# Function value obtained: -0.8411
# Current minimum: -0.8633
# Iteration No: 11 started. Evaluating function at random point.
# [0.01909842850485622, 3, 12, 0.6728679300083596, 0.944578432980404, 528]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9699905815870026
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 0.1785
# Function value obtained: -0.8647
# Current minimum: -0.8647
# Iteration No: 12 started. Evaluating function at random point.
# [0.0012116790683302117, 3, 2, 0.06616307483844217, 0.23025600705315752, 677]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9487756063103367
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 0.1985
# Function value obtained: -0.7551
# Current minimum: -0.8647
# Iteration No: 13 started. Evaluating function at random point.
# [0.004203255075983761, 7, 16, 0.3563517753435657, 0.394574367546406, 665]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9685542736048974
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 0.6104
# Function value obtained: -0.8581
# Current minimum: -0.8647
# Iteration No: 14 started. Evaluating function at random point.
# [0.02151017641719756, 8, 12, 0.3478164905580535, 0.6097479658465779, 898]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9685071815399106
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 0.9281
# Function value obtained: -0.8493
# Current minimum: -0.8647
# Iteration No: 15 started. Evaluating function at random point.
# [0.0021108116772730425, 2, 10, 0.7397664605754514, 0.5409573219011281, 169]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.936796562279256
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 0.0507
# Function value obtained: -0.6370
# Current minimum: -0.8647
# Iteration No: 16 started. Evaluating function at random point.
# [0.0022449729419144397, 4, 5, 0.3108581988504267, 0.9309012838296121, 403]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9641864845773488
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 0.1729
# Function value obtained: -0.8207
# Current minimum: -0.8647
# Iteration No: 17 started. Evaluating function at random point.
# [0.015665337619230394, 4, 12, 0.6379996920535315, 0.44547029713921693, 274]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9658582528843889
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 0.1172
# Function value obtained: -0.8414
# Current minimum: -0.8647
# Iteration No: 18 started. Evaluating function at random point.
# [0.061810855225848234, 9, 13, 0.6999267156375811, 0.7080093169433413, 131]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9700612196844832
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 0.2176
# Function value obtained: -0.8580
# Current minimum: -0.8647
# Iteration No: 19 started. Evaluating function at random point.
# [0.0066328042405379645, 8, 6, 0.5976582413192033, 0.2474882432951916, 516]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9642571226748293
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 0.6604
# Function value obtained: -0.8332
# Current minimum: -0.8647
# Iteration No: 20 started. Evaluating function at random point.
# [0.003859705757436628, 2, 11, 0.19148421730222298, 0.5852444922406691, 613]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9532316929597362
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 0.3164
# Function value obtained: -0.7434
# Current minimum: -0.8647
# Iteration No: 21 started. Searching for the next optimal point.
# [0.005525329343676573, 6, 19, 0.7540261531219052, 0.9023706439854693, 123]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9662997409936426
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.2724
# Function value obtained: -0.8441
# Current minimum: -0.8647
# Iteration No: 22 started. Searching for the next optimal point.
# [0.00656547647946506, 5, 17, 0.9568536815455827, 0.9300925058102837, 180]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9653814457263952
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 0.2858
# Function value obtained: -0.8332
# Current minimum: -0.8647
# Iteration No: 23 started. Searching for the next optimal point.
# [0.001293144574635106, 9, 14, 0.8007405138563727, 0.6788279830754043, 117]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9687073228161055
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.4171
# Function value obtained: -0.8578
# Current minimum: -0.8647
# Iteration No: 24 started. Searching for the next optimal point.
# [0.0015234944083255407, 6, 10, 0.8337846310751739, 0.8672068722131671, 157]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9656463385919473
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.3072
# Function value obtained: -0.8396
# Current minimum: -0.8647
# Iteration No: 25 started. Searching for the next optimal point.
# [0.0017233846131992463, 5, 14, 0.9316009438612194, 0.9063992143215112, 208]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9629503178714387
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 0.2981
# Function value obtained: -0.8067
# Current minimum: -0.8647
# Iteration No: 26 started. Searching for the next optimal point.
# [0.0018010222915556967, 8, 14, 0.9599025248315586, 0.49878097057703114, 764]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9676359783376501
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 1.2848
# Function value obtained: -0.8568
# Current minimum: -0.8647
# Iteration No: 27 started. Searching for the next optimal point.
# [0.0100741547229517, 4, 13, 0.938780543459168, 0.4888786849035731, 206]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9645514480809984
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 0.3165
# Function value obtained: -0.8385
# Current minimum: -0.8647
# Iteration No: 28 started. Searching for the next optimal point.
# [0.0019329139178001014, 4, 20, 0.8523805025658874, 0.6388882654406911, 113]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9606486931951966
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 0.2268
# Function value obtained: -0.8165
# Current minimum: -0.8647
# Iteration No: 29 started. Searching for the next optimal point.
# [0.015592788079224845, 3, 12, 0.94759696237284, 0.9329399689668925, 342]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9647986814221804
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 0.2928
# Function value obtained: -0.8136
# Current minimum: -0.8647
# Iteration No: 30 started. Searching for the next optimal point.
# [0.003721800895525211, 4, 7, 0.7530665701293057, 0.39200751539268675, 203]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9589945844125265
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.2566
# Function value obtained: -0.8073
# Current minimum: -0.8647
# Iteration No: 31 started. Searching for the next optimal point.
# [0.005911278490493313, 3, 11, 0.5692770901577322, 0.9886889721002969, 192]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.958400047092065
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 0.2447
# Function value obtained: -0.7608
# Current minimum: -0.8647
# Iteration No: 32 started. Searching for the next optimal point.
# [0.0015616278397814255, 8, 13, 0.9483132880247601, 0.9572606769759056, 167]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9665116552860843
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 0.4673
# Function value obtained: -0.8447
# Current minimum: -0.8647
# Iteration No: 33 started. Searching for the next optimal point.
# [0.0013451386465843397, 5, 13, 0.8799868261535412, 0.9279322277708317, 918]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9665175417942077
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 0.7014
# Function value obtained: -0.8430
# Current minimum: -0.8647
# Iteration No: 34 started. Searching for the next optimal point.
# [0.0016448112227961322, 3, 17, 0.9489557368245853, 0.9937857105721125, 782]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9581881327996233
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 0.4287
# Function value obtained: -0.7614
# Current minimum: -0.8647
# Iteration No: 35 started. Searching for the next optimal point.
# [0.05369637028821357, 5, 11, 0.6890009332885735, 0.9847172615036174, 751]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9684129974099364
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.5446
# Function value obtained: -0.8479
# Current minimum: -0.8647
# Iteration No: 36 started. Searching for the next optimal point.
# [0.08331114229035605, 5, 9, 0.3643950564955481, 0.9906617416013421, 943]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9671768307040264
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 0.7193
# Function value obtained: -0.8395
# Current minimum: -0.8647
# Iteration No: 37 started. Searching for the next optimal point.
# [0.04521751694058623, 1, 17, 0.7181104007958714, 0.9112273418223608, 950]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9545384977631269
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 0.4663
# Function value obtained: -0.7326
# Current minimum: -0.8647
# Iteration No: 38 started. Searching for the next optimal point.
# [0.03079878477806424, 3, 8, 0.7429789224538876, 0.5169748398240713, 699]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9688721450435601
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 0.4301
# Function value obtained: -0.8593
# Current minimum: -0.8647
# Iteration No: 39 started. Searching for the next optimal point.
# [0.04674734383675146, 3, 8, 0.5846854419280262, 0.6067271596877173, 886]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9697551212620673
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 0.4633
# Function value obtained: -0.8607
# Current minimum: -0.8647
# Iteration No: 40 started. Searching for the next optimal point.
# [0.01925783855715763, 3, 5, 0.4346892304466937, 0.13861783187154791, 168]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9494937603013892
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 0.2989
# Function value obtained: -0.7458
# Current minimum: -0.8647
# Iteration No: 41 started. Searching for the next optimal point.
# [0.03134147147287125, 3, 2, 0.6516038714605906, 0.509919500100003, 815]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9690487402872615
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 0.4947
# Function value obtained: -0.8599
# Current minimum: -0.8647
# Iteration No: 42 started. Searching for the next optimal point.
# [0.07073635306594658, 3, 5, 0.5317403079892757, 0.49216807159362447, 835]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9665646338591947
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 0.4191
# Function value obtained: -0.8319
# Current minimum: -0.8647
# Iteration No: 43 started. Searching for the next optimal point.
# [0.03936905276841413, 2, 6, 0.7918866173065845, 0.466372877740436, 776]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9674417235695786
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 0.4505
# Function value obtained: -0.8481
# Current minimum: -0.8647
# Iteration No: 44 started. Searching for the next optimal point.
# [0.032138925499558504, 2, 8, 0.6306250374975405, 0.8010162125866542, 888]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9690016482222745
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 0.3928
# Function value obtained: -0.8529
# Current minimum: -0.8647
# Iteration No: 45 started. Searching for the next optimal point.
# [0.03115264589756688, 1, 7, 0.6451023090692487, 0.6186049618226017, 867]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.952766658817989
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 0.3647
# Function value obtained: -0.7212
# Current minimum: -0.8647
# Iteration No: 46 started. Searching for the next optimal point.
# [0.017684453836068918, 2, 11, 0.940671540216448, 0.32929411996261615, 705]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9631210266070167
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 0.3420
# Function value obtained: -0.8169
# Current minimum: -0.8647
# Iteration No: 47 started. Searching for the next optimal point.
# [0.005846046437127017, 2, 9, 0.5768656912336872, 0.8176327531957911, 841]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9582823169295973
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 0.4114
# Function value obtained: -0.7593
# Current minimum: -0.8647
# Iteration No: 48 started. Searching for the next optimal point.
# [0.028680966562465177, 2, 5, 0.6846168520937657, 0.9997460916318698, 314]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9630386154932894
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 0.3400
# Function value obtained: -0.8051
# Current minimum: -0.8647
# Iteration No: 49 started. Searching for the next optimal point.
# [0.018996058737510015, 3, 9, 0.4920202907903222, 0.09331820193158846, 886]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9540970096538733
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 0.4318
# Function value obtained: -0.7433
# Current minimum: -0.8647
# Iteration No: 50 started. Searching for the next optimal point.
# [0.03133317791482948, 3, 19, 0.07944816134100702, 0.5919343412547559, 882]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.968883918059807
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 0.4464
# Function value obtained: -0.8407
# Current minimum: -0.8647

# %%
params = res.x

# %%
import pickle

pickle.dump(params,open('data/params/lgbm.pickle','wb'))

# %% [markdown]
# ## RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
def tune_rf(params):
    print(params)
    
    bootstrap = params[0]
    max_depth = params[1]
    max_features = params[2]
    min_samples_leaf = params[3]
    min_samples_split = params[4]
    n_estimators = params[5]

    
    
    mdl = RandomForestClassifier(bootstrap=bootstrap, max_depth=max_depth, \
     max_features=max_features, min_samples_leaf=min_samples_leaf, \
        min_samples_split=min_samples_split, n_estimators=n_estimators,    \
                                 random_state=0, 
                         class_weight="balanced", n_jobs=-1)
    mdl.fit(X_train, y_train)
    
    p = mdl.predict_proba(X_valid)[:, 1]
    
    print(roc_auc_score(y_valid, p))
    
    return -average_precision_score(y_valid, p)


space = {'bootstrap': [True, False],
 'max_depth': [10, 20, None],
 'max_features': ['auto', 'sqrt'],
 'min_samples_leaf': [1, 4],
 'min_samples_split': [2, 10],
 'n_estimators': [200, 1000]}

space = list(space.values())
print(space)

res = forest_minimize(tune_rf, space, random_state=160745, n_random_starts=20, n_calls=50, verbose=1)
# Out:
# [[True, False], [10, 20, None], ['auto', 'sqrt'], [1, 4], [2, 10], [200, 1000]]
# Iteration No: 1 started. Evaluating function at random point.
# [True, 20, 'sqrt', 3, 9, 208]
# 0.9678832116788321
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.4848
# Function value obtained: -0.8488
# Current minimum: -0.8488
# Iteration No: 2 started. Evaluating function at random point.
# [True, 20, 'auto', 3, 7, 700]
# 0.9683659053449494
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 1.5672
# Function value obtained: -0.8498
# Current minimum: -0.8498
# Iteration No: 3 started. Evaluating function at random point.
# [False, None, 'sqrt', 4, 5, 883]
# 0.9661408052743112
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 2.2167
# Function value obtained: -0.8358
# Current minimum: -0.8498
# Iteration No: 4 started. Evaluating function at random point.
# [True, 20, 'sqrt', 3, 10, 592]
# 0.968283494231222
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 1.2496
# Function value obtained: -0.8520
# Current minimum: -0.8520
# Iteration No: 5 started. Evaluating function at random point.
# [False, None, 'auto', 1, 2, 591]
# 0.9497586531669414
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 1.4418
# Function value obtained: -0.7645
# Current minimum: -0.8520
# Iteration No: 6 started. Evaluating function at random point.
# [True, 20, 'sqrt', 4, 2, 807]
# 0.9682952672474687
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 1.7779
# Function value obtained: -0.8536
# Current minimum: -0.8536
# Iteration No: 7 started. Evaluating function at random point.
# [True, None, 'auto', 1, 6, 506]
# 0.9670237814928184
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 1.1405
# Function value obtained: -0.8402
# Current minimum: -0.8536
# Iteration No: 8 started. Evaluating function at random point.
# [False, None, 'auto', 1, 8, 206]
# 0.9641982575935955
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.4943
# Function value obtained: -0.8232
# Current minimum: -0.8536
# Iteration No: 9 started. Evaluating function at random point.
# [False, None, 'auto', 2, 4, 691]
# 0.9651754179420767
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 1.7055
# Function value obtained: -0.8314
# Current minimum: -0.8536
# Iteration No: 10 started. Evaluating function at random point.
# [True, 20, 'auto', 1, 7, 832]
# 0.9674593830939486
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 1.8036
# Function value obtained: -0.8453
# Current minimum: -0.8536
# Iteration No: 11 started. Evaluating function at random point.
# [False, 20, 'sqrt', 4, 5, 628]
# 0.9663644925829998
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 1.4890
# Function value obtained: -0.8392
# Current minimum: -0.8536
# Iteration No: 12 started. Evaluating function at random point.
# [True, 20, 'auto', 2, 2, 549]
# 0.9673181068989876
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 1.2546
# Function value obtained: -0.8417
# Current minimum: -0.8536
# Iteration No: 13 started. Evaluating function at random point.
# [True, 20, 'auto', 3, 8, 220]
# 0.9680715799387803
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 0.5137
# Function value obtained: -0.8508
# Current minimum: -0.8536
# Iteration No: 14 started. Evaluating function at random point.
# [True, 20, 'auto', 4, 6, 397]
# 0.967741935483871
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 0.8713
# Function value obtained: -0.8525
# Current minimum: -0.8536
# Iteration No: 15 started. Evaluating function at random point.
# [False, 20, 'sqrt', 3, 6, 623]
# 0.9659995290793502
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 1.5066
# Function value obtained: -0.8387
# Current minimum: -0.8536
# Iteration No: 16 started. Evaluating function at random point.
# [False, 20, 'sqrt', 1, 9, 234]
# 0.9642571226748293
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 0.5893
# Function value obtained: -0.8275
# Current minimum: -0.8536
# Iteration No: 17 started. Evaluating function at random point.
# [False, 20, 'sqrt', 3, 5, 403]
# 0.9656698846244407
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 1.3463
# Function value obtained: -0.8359
# Current minimum: -0.8536
# Iteration No: 18 started. Evaluating function at random point.
# [False, 20, 'auto', 2, 10, 599]
# 0.9654815163644925
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 1.9828
# Function value obtained: -0.8345
# Current minimum: -0.8536
# Iteration No: 19 started. Evaluating function at random point.
# [False, 10, 'auto', 3, 9, 877]
# 0.9658935719331293
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 2.7864
# Function value obtained: -0.8434
# Current minimum: -0.8536
# Iteration No: 20 started. Evaluating function at random point.
# [False, 10, 'auto', 4, 3, 293]
# 0.9657993878031552
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 1.1434
# Function value obtained: -0.8442
# Current minimum: -0.8536
# Iteration No: 21 started. Searching for the next optimal point.
# [False, None, 'auto', 4, 10, 973]
# 0.9661290322580645
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 3.5035
# Function value obtained: -0.8390
# Current minimum: -0.8536
# Iteration No: 22 started. Searching for the next optimal point.
# [True, 10, 'sqrt', 1, 3, 992]
# 0.9666705910054156
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 2.9054
# Function value obtained: -0.8440
# Current minimum: -0.8536
# Iteration No: 23 started. Searching for the next optimal point.
# [True, None, 'sqrt', 1, 3, 625]
# 0.9661643513068048
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 2.0739
# Function value obtained: -0.8381
# Current minimum: -0.8536
# Iteration No: 24 started. Searching for the next optimal point.
# [False, None, 'sqrt', 1, 2, 560]
# 0.9496997880857077
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 1.7610
# Function value obtained: -0.7640
# Current minimum: -0.8536
# Iteration No: 25 started. Searching for the next optimal point.
# [True, 20, 'sqrt', 4, 2, 588]
# 0.9681068989875207
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 1.6462
# Function value obtained: -0.8526
# Current minimum: -0.8536
# Iteration No: 26 started. Searching for the next optimal point.
# [True, None, 'sqrt', 3, 3, 960]
# 0.9679891688250529
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 2.5158
# Function value obtained: -0.8484
# Current minimum: -0.8536
# Iteration No: 27 started. Searching for the next optimal point.
# [False, 10, 'auto', 2, 3, 291]
# 0.9650812338121026
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 1.1156
# Function value obtained: -0.8387
# Current minimum: -0.8536
# Iteration No: 28 started. Searching for the next optimal point.
# [False, 10, 'sqrt', 1, 6, 550]
# 0.9652460560395573
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 1.8757
# Function value obtained: -0.8402
# Current minimum: -0.8536
# Iteration No: 29 started. Searching for the next optimal point.
# [True, None, 'auto', 1, 8, 230]
# 0.9675535672239228
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 0.7739
# Function value obtained: -0.8468
# Current minimum: -0.8536
# Iteration No: 30 started. Searching for the next optimal point.
# [False, 10, 'auto', 1, 2, 238]
# 0.9650576877796092
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.9011
# Function value obtained: -0.8375
# Current minimum: -0.8536
# Iteration No: 31 started. Searching for the next optimal point.
# [False, None, 'sqrt', 4, 2, 616]
# 0.9661290322580646
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 2.2433
# Function value obtained: -0.8366
# Current minimum: -0.8536
# Iteration No: 32 started. Searching for the next optimal point.
# [False, None, 'sqrt', 3, 2, 511]
# 0.9657522957381681
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 1.6714
# Function value obtained: -0.8367
# Current minimum: -0.8536
# Iteration No: 33 started. Searching for the next optimal point.
# [False, None, 'sqrt', 2, 2, 373]
# 0.964916411584648
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 1.3610
# Function value obtained: -0.8288
# Current minimum: -0.8536
# Iteration No: 34 started. Searching for the next optimal point.
# [False, None, 'sqrt', 2, 2, 582]
# 0.9648457734871674
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 2.1488
# Function value obtained: -0.8298
# Current minimum: -0.8536
# Iteration No: 35 started. Searching for the next optimal point.
# [False, None, 'auto', 3, 2, 890]
# 0.9660230751118436
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 4.1831
# Function value obtained: -0.8373
# Current minimum: -0.8536
# Iteration No: 36 started. Searching for the next optimal point.
# [False, 10, 'auto', 1, 2, 645]
# 0.9649870496821286
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 2.0173
# Function value obtained: -0.8372
# Current minimum: -0.8536
# Iteration No: 37 started. Searching for the next optimal point.
# [False, None, 'auto', 3, 8, 569]
# 0.9665057687779609
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 2.0941
# Function value obtained: -0.8377
# Current minimum: -0.8536
# Iteration No: 38 started. Searching for the next optimal point.
# [False, None, 'sqrt', 1, 5, 958]
# 0.9640687544148812
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 4.2138
# Function value obtained: -0.8110
# Current minimum: -0.8536
# Iteration No: 39 started. Searching for the next optimal point.
# [False, None, 'auto', 1, 10, 701]
# 0.9654461973157524
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 2.6569
# Function value obtained: -0.8313
# Current minimum: -0.8536
# Iteration No: 40 started. Searching for the next optimal point.
# [False, None, 'auto', 1, 2, 907]
# 0.9497233341182012
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 3.2696
# Function value obtained: -0.7659
# Current minimum: -0.8536
# Iteration No: 41 started. Searching for the next optimal point.
# [False, None, 'sqrt', 1, 5, 490]
# 0.9637037909112315
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 1.7060
# Function value obtained: -0.8124
# Current minimum: -0.8536
# Iteration No: 42 started. Searching for the next optimal point.
# [True, 20, 'sqrt', 1, 2, 981]
# 0.9651518719095832
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 2.7762
# Function value obtained: -0.8378
# Current minimum: -0.8536
# Iteration No: 43 started. Searching for the next optimal point.
# [True, None, 'auto', 1, 2, 483]
# 0.9618966329173534
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 1.4966
# Function value obtained: -0.8295
# Current minimum: -0.8536
# Iteration No: 44 started. Searching for the next optimal point.
# [True, None, 'auto', 1, 2, 341]
# 0.961655286084295
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 1.2152
# Function value obtained: -0.8299
# Current minimum: -0.8536
# Iteration No: 45 started. Searching for the next optimal point.
# [False, None, 'auto', 1, 4, 826]
# 0.9574523192842006
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 2.5570
# Function value obtained: -0.8013
# Current minimum: -0.8536
# Iteration No: 46 started. Searching for the next optimal point.
# [False, None, 'auto', 1, 10, 210]
# 0.9649046385684013
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 0.8409
# Function value obtained: -0.8277
# Current minimum: -0.8536
# Iteration No: 47 started. Searching for the next optimal point.
# [False, None, 'auto', 2, 2, 953]
# 0.964916411584648
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 3.2802
# Function value obtained: -0.8298
# Current minimum: -0.8536
# Iteration No: 48 started. Searching for the next optimal point.
# [False, None, 'sqrt', 1, 9, 768]
# 0.9651283258770897
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 2.7280
# Function value obtained: -0.8259
# Current minimum: -0.8536
# Iteration No: 49 started. Searching for the next optimal point.
# [True, None, 'sqrt', 1, 2, 519]
# 0.9620379091123147
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 1.6501
# Function value obtained: -0.8309
# Current minimum: -0.8536
# Iteration No: 50 started. Searching for the next optimal point.
# [False, None, 'auto', 1, 6, 553]
# 0.9638097480574523
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 2.0312
# Function value obtained: -0.8074
# Current minimum: -0.8536

# %%
params = res.x

# %%
import pickle

pickle.dump(params,open('data/params/rf.pickle','wb'))

# %% [markdown]
# ## Logistic Regressor

# %%
from sklearn.linear_model import LogisticRegression
def tune_lr(params):
    print(params)
    
    C = params[0]
    solver = params[1]

    mdl = LogisticRegression(C=C, solver=solver,\
                         class_weight="balanced", n_jobs=-1)
    mdl.fit(X_train, y_train)
    
    p = mdl.predict_proba(X_valid)[:, 1]
    
    print(roc_auc_score(y_valid, p))
    
    return -average_precision_score(y_valid, p)


space = {'C': [1, 10],
 'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
        }

space = list(space.values())
print(space)

res = forest_minimize(tune_lr, space, random_state=160745, n_random_starts=20, n_calls=50, verbose=1)
# Out:
# [[1, 10], ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']]
# Iteration No: 1 started. Evaluating function at random point.
# [5, 'lbfgs']
# 0.9375441488109254
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.7396
# Function value obtained: -0.6452
# Current minimum: -0.6452
# Iteration No: 2 started. Evaluating function at random point.
# [1, 'liblinear']
# 0.9368259948198729
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.0517
# Function value obtained: -0.6437
# Current minimum: -0.6452
# Iteration No: 3 started. Evaluating function at random point.
# [8, 'sag']
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   warnings.warn("'n_jobs' > 1 does not have any effect when"
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 0.9315045914763362
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.1773
# Function value obtained: -0.6171
# Current minimum: -0.6452
# Iteration No: 4 started. Evaluating function at random point.
# [9, 'saga']
# 0.9284906993171651
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.1655
# Function value obtained: -0.6018
# Current minimum: -0.6452
# Iteration No: 5 started. Evaluating function at random point.
# [1, 'sag']
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 0.9314574994113491
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.1535
# Function value obtained: -0.6164
# Current minimum: -0.6452
# Iteration No: 6 started. Evaluating function at random point.
# [6, 'newton-cg']
# 0.9376030138921592
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.4181
# Function value obtained: -0.6454
# Current minimum: -0.6454
# Iteration No: 7 started. Evaluating function at random point.
# [5, 'saga']
# 0.9285260183659053
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.1957
# Function value obtained: -0.6020
# Current minimum: -0.6454
# Iteration No: 8 started. Evaluating function at random point.
# [4, 'saga']
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 0.9284906993171651
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.1786
# Function value obtained: -0.6018
# Current minimum: -0.6454
# Iteration No: 9 started. Evaluating function at random point.
# [9, 'lbfgs']
# 0.9376736519896398
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.4503
# Function value obtained: -0.6457
# Current minimum: -0.6457
# Iteration No: 10 started. Evaluating function at random point.
# [9, 'sag']
# 0.931516364492583
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.1655
# Function value obtained: -0.6175
# Current minimum: -0.6457
# Iteration No: 11 started. Evaluating function at random point.
# [9, 'sag']
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 0.9315399105250766
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 0.1540
# Function value obtained: -0.6170
# Current minimum: -0.6457
# Iteration No: 12 started. Evaluating function at random point.
# [10, 'sag']
# 0.931516364492583
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 0.1857
# Function value obtained: -0.6170
# Current minimum: -0.6457
# Iteration No: 13 started. Evaluating function at random point.
# [10, 'saga']
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 0.9284906993171651
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 0.2148
# Function value obtained: -0.6018
# Current minimum: -0.6457
# Iteration No: 14 started. Evaluating function at random point.
# [8, 'lbfgs']
# 0.9376736519896397
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 0.4417
# Function value obtained: -0.6456
# Current minimum: -0.6457
# Iteration No: 15 started. Evaluating function at random point.
# [6, 'newton-cg']
# 0.9376030138921592
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 0.4314
# Function value obtained: -0.6454
# Current minimum: -0.6457
# Iteration No: 16 started. Evaluating function at random point.
# [1, 'lbfgs']
# 0.9369084059336001
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 0.4476
# Function value obtained: -0.6437
# Current minimum: -0.6457
# Iteration No: 17 started. Evaluating function at random point.
# [10, 'newton-cg']
# 0.93770897103838
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 0.4607
# Function value obtained: -0.6459
# Current minimum: -0.6459
# Iteration No: 18 started. Evaluating function at random point.
# [9, 'lbfgs']
# 0.9376736519896398
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 0.4631
# Function value obtained: -0.6457
# Current minimum: -0.6459
# Iteration No: 19 started. Evaluating function at random point.
# [5, 'newton-cg']
# 0.9375559218271722
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 0.0785
# Function value obtained: -0.6452
# Current minimum: -0.6459
# Iteration No: 20 started. Evaluating function at random point.
# [3, 'liblinear']
# 0.9372733694372498
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   warnings.warn("'n_jobs' > 1 does not have any effect when"
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 0.2348
# Function value obtained: -0.6438
# Current minimum: -0.6459
# Iteration No: 21 started. Searching for the next optimal point.
# [3, 'newton-cg']
# 0.9373322345184836
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.3593
# Function value obtained: -0.6439
# Current minimum: -0.6459
# Iteration No: 22 started. Searching for the next optimal point.
# [4, 'lbfgs']
# 0.9375088297621851
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 0.2642
# Function value obtained: -0.6448
# Current minimum: -0.6459
# Iteration No: 23 started. Searching for the next optimal point.
# [3, 'newton-cg']
# 0.9373322345184836
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.2664
# Function value obtained: -0.6439
# Current minimum: -0.6459
# Iteration No: 24 started. Searching for the next optimal point.
# [5, 'liblinear']
# 0.9374852837296915
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   warnings.warn("'n_jobs' > 1 does not have any effect when"
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.2399
# Function value obtained: -0.6450
# Current minimum: -0.6459
# Iteration No: 25 started. Searching for the next optimal point.
# [9, 'liblinear']
# 0.9376736519896398
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   warnings.warn("'n_jobs' > 1 does not have any effect when"
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 0.2306
# Function value obtained: -0.6456
# Current minimum: -0.6459
# Iteration No: 26 started. Searching for the next optimal point.
# [7, 'liblinear']
# 0.9375794678596657
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   warnings.warn("'n_jobs' > 1 does not have any effect when"
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 0.2329
# Function value obtained: -0.6452
# Current minimum: -0.6459
# Iteration No: 27 started. Searching for the next optimal point.
# [10, 'liblinear']
# 0.9376854250058865
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   warnings.warn("'n_jobs' > 1 does not have any effect when"
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 0.2331
# Function value obtained: -0.6457
# Current minimum: -0.6459
# Iteration No: 28 started. Searching for the next optimal point.
# [4, 'newton-cg']
# 0.9375206027784319
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 0.2647
# Function value obtained: -0.6449
# Current minimum: -0.6459
# Iteration No: 29 started. Searching for the next optimal point.
# [2, 'lbfgs']
# 0.9372027313397693
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 0.2623
# Function value obtained: -0.6439
# Current minimum: -0.6459
# Iteration No: 30 started. Searching for the next optimal point.
# [4, 'liblinear']
# 0.9374028726159642
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   warnings.warn("'n_jobs' > 1 does not have any effect when"
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.2325
# Function value obtained: -0.6443
# Current minimum: -0.6459
# Iteration No: 31 started. Searching for the next optimal point.
# [6, 'liblinear']
# 0.9375323757946786
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   warnings.warn("'n_jobs' > 1 does not have any effect when"
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 0.2318
# Function value obtained: -0.6452
# Current minimum: -0.6459
# Iteration No: 32 started. Searching for the next optimal point.
# [4, 'liblinear']
# 0.9374028726159642
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   warnings.warn("'n_jobs' > 1 does not have any effect when"
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 0.3207
# Function value obtained: -0.6443
# Current minimum: -0.6459
# Iteration No: 33 started. Searching for the next optimal point.
# [8, 'liblinear']
# 0.9376501059571463
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   warnings.warn("'n_jobs' > 1 does not have any effect when"
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 0.2502
# Function value obtained: -0.6454
# Current minimum: -0.6459
# Iteration No: 34 started. Searching for the next optimal point.
# [2, 'newton-cg']
# 0.937214504356016
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 0.2597
# Function value obtained: -0.6439
# Current minimum: -0.6459
# Iteration No: 35 started. Searching for the next optimal point.
# [3, 'lbfgs']
# 0.9373204615022369
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.2813
# Function value obtained: -0.6439
# Current minimum: -0.6459
# Iteration No: 36 started. Searching for the next optimal point.
# [4, 'newton-cg']
# 0.9375206027784319
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 0.2732
# Function value obtained: -0.6449
# Current minimum: -0.6459
# Iteration No: 37 started. Searching for the next optimal point.
# [1, 'newton-cg']
# 0.9369084059336001
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 0.2790
# Function value obtained: -0.6437
# Current minimum: -0.6459
# Iteration No: 38 started. Searching for the next optimal point.
# [4, 'newton-cg']
# 0.9375206027784319
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 0.2739
# Function value obtained: -0.6449
# Current minimum: -0.6459
# Iteration No: 39 started. Searching for the next optimal point.
# [5, 'liblinear']
# 0.9374852837296915
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   warnings.warn("'n_jobs' > 1 does not have any effect when"
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 0.2504
# Function value obtained: -0.6450
# Current minimum: -0.6459
# Iteration No: 40 started. Searching for the next optimal point.
# [9, 'newton-cg']
# 0.9376971980221334
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 0.2689
# Function value obtained: -0.6458
# Current minimum: -0.6459
# Iteration No: 41 started. Searching for the next optimal point.
# [7, 'lbfgs']
# 0.9376383329408994
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 0.2953
# Function value obtained: -0.6455
# Current minimum: -0.6459
# Iteration No: 42 started. Searching for the next optimal point.
# [4, 'lbfgs']
# 0.9375088297621851
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 0.3650
# Function value obtained: -0.6448
# Current minimum: -0.6459
# Iteration No: 43 started. Searching for the next optimal point.
# [3, 'lbfgs']
# 0.9373204615022369
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 0.2690
# Function value obtained: -0.6439
# Current minimum: -0.6459
# Iteration No: 44 started. Searching for the next optimal point.
# [4, 'lbfgs']
# 0.9375088297621851
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 0.2906
# Function value obtained: -0.6448
# Current minimum: -0.6459
# Iteration No: 45 started. Searching for the next optimal point.
# [4, 'liblinear']
# 0.9374028726159642
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   warnings.warn("'n_jobs' > 1 does not have any effect when"
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 0.2398
# Function value obtained: -0.6443
# Current minimum: -0.6459
# Iteration No: 46 started. Searching for the next optimal point.
# [2, 'newton-cg']
# 0.937214504356016
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 0.2829
# Function value obtained: -0.6439
# Current minimum: -0.6459
# Iteration No: 47 started. Searching for the next optimal point.
# [8, 'newton-cg']
# 0.9376736519896397
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 0.3021
# Function value obtained: -0.6456
# Current minimum: -0.6459
# Iteration No: 48 started. Searching for the next optimal point.
# [7, 'newton-cg']
# 0.9376618789733929
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 0.2826
# Function value obtained: -0.6455
# Current minimum: -0.6459
# Iteration No: 49 started. Searching for the next optimal point.
# [10, 'newton-cg']
# 0.93770897103838
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 0.2922
# Function value obtained: -0.6459
# Current minimum: -0.6459
# Iteration No: 50 started. Searching for the next optimal point.
# [7, 'sag']
# 0.931516364492583
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 0.4119
# Function value obtained: -0.6175
# Current minimum: -0.6459

# %%
params = res.x

import pickle

pickle.dump(params,open('data/params/lr.pickle','wb'))
# Out:
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/kevintakano/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
